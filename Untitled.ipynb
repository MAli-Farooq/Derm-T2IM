# %%
import warnings
warnings.filterwarnings('ignore')
from torchvision import models
import numpy as np
import cv2
import requests
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image, \
    deprocess_image, \
    preprocess_image
from PIL import Image

model = models.resnet50(pretrained=True)
model.eval()
image_url = "https://th.bing.com/th/id/R.94b33a074b9ceeb27b1c7fba0f66db74?rik=wN27mvigyFlXGg&riu=http%3a%2f%2fimages5.fanpop.com%2fimage%2fphotos%2f31400000%2fBear-Wallpaper-bears-31446777-1600-1200.jpg&ehk=oD0JPpRVTZZ6yizZtGQtnsBGK2pAap2xv3sU3A4bIMc%3d&risl=&pid=ImgRaw&r=0"
img = np.array(Image.open(requests.get(image_url, stream=True).raw))
img = cv2.resize(img, (224, 224))
img = np.float32(img) / 255
input_tensor = preprocess_image(img, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

# The target for the CAM is the Bear category.
# As usual for classication, the target is the logit output
# before softmax, for that category.
targets = [ClassifierOutputTarget(295)]
target_layers = [model.layer4]
with GradCAM(model=model, target_layers=target_layers) as cam:
    grayscale_cams = cam(input_tensor=input_tensor, targets=targets)
    cam_image = show_cam_on_image(img, grayscale_cams[0, :], use_rgb=True)
cam = np.uint8(255*grayscale_cams[0, :])
cam = cv2.merge([cam, cam, cam])
images = np.hstack((np.uint8(255*img), cam , cam_image))
Image.fromarray(images)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /home/ali/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 97.8M/97.8M [00:09<00:00, 11.3MB/s]
# <PIL.Image.Image image mode=RGB size=672x224 at 0x7F88D7314A60>

# %%
import warnings
warnings.filterwarnings('ignore')
from torchvision import models
import numpy as np
import cv2
import requests
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image, \
    deprocess_image, \
    preprocess_image
from PIL import Image

# %%
model = models.resnet50(pretrained=True)
model.eval()
image_url = "https://th.bing.com/th/id/R.94b33a074b9ceeb27b1c7fba0f66db74?rik=wN27mvigyFlXGg&riu=http%3a%2f%2fimages5.fanpop.com%2fimage%2fphotos%2f31400000%2fBear-Wallpaper-bears-31446777-1600-1200.jpg&ehk=oD0JPpRVTZZ6yizZtGQtnsBGK2pAap2xv3sU3A4bIMc%3d&risl=&pid=ImgRaw&r=0"
img = np.array(Image.open(requests.get(image_url, stream=True).raw))
img = cv2.resize(img, (224, 224))
img = np.float32(img) / 255
input_tensor = preprocess_image(img, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

# %%
# The target for the CAM is the Bear category.
# As usual for classication, the target is the logit output
# before softmax, for that category.
targets = [ClassifierOutputTarget(295)]
target_layers = [model.layer4]
with GradCAM(model=model, target_layers=target_layers) as cam:
    grayscale_cams = cam(input_tensor=input_tensor, targets=targets)
    cam_image = show_cam_on_image(img, grayscale_cams[0, :], use_rgb=True)
cam = np.uint8(255*grayscale_cams[0, :])
cam = cv2.merge([cam, cam, cam])
images = np.hstack((np.uint8(255*img), cam , cam_image))
Image.fromarray(images)
# Out:
# <PIL.Image.Image image mode=RGB size=672x224 at 0x7F2A944F17F0>

# %%
# !pip install pytorch-gradcam
# Out:
# Requirement already satisfied: pytorch-gradcam in /home/ali/.local/lib/python3.8/site-packages (0.2.1)
# Requirement already satisfied: numpy in /home/ali/.local/lib/python3.8/site-packages (from pytorch-gradcam) (1.24.4)
# Requirement already satisfied: opencv-python in /home/ali/.local/lib/python3.8/site-packages (from pytorch-gradcam) (4.7.0.72)

# %%
# !pip install grad-cam
# Out:
# Requirement already satisfied: grad-cam in /home/ali/.local/lib/python3.8/site-packages (1.4.8)
# Requirement already satisfied: Pillow in /home/ali/.local/lib/python3.8/site-packages (from grad-cam) (10.0.1)
# Requirement already satisfied: torchvision>=0.8.2 in /home/ali/.local/lib/python3.8/site-packages (from grad-cam) (0.15.2)
# Requirement already satisfied: opencv-python in /home/ali/.local/lib/python3.8/site-packages (from grad-cam) (4.7.0.72)
# Requirement already satisfied: tqdm in /home/ali/.local/lib/python3.8/site-packages (from grad-cam) (4.65.0)
# Requirement already satisfied: numpy in /home/ali/.local/lib/python3.8/site-packages (from grad-cam) (1.24.4)
# Requirement already satisfied: scikit-learn in /home/ali/.local/lib/python3.8/site-packages (from grad-cam) (1.3.0)
# Requirement already satisfied: torch>=1.7.1 in /home/ali/.local/lib/python3.8/site-packages (from grad-cam) (2.0.1)
# Requirement already satisfied: ttach in /home/ali/.local/lib/python3.8/site-packages (from grad-cam) (0.0.3)
# Requirement already satisfied: matplotlib in /home/ali/.local/lib/python3.8/site-packages (from grad-cam) (3.7.3)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from torchvision>=0.8.2->grad-cam) (2.22.0)
# Requirement already satisfied: scipy>=1.5.0 in /home/ali/.local/lib/python3.8/site-packages (from scikit-learn->grad-cam) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/ali/.local/lib/python3.8/site-packages (from scikit-learn->grad-cam) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ali/.local/lib/python3.8/site-packages (from scikit-learn->grad-cam) (3.2.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (11.7.99)
# Requirement already satisfied: typing-extensions in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (4.5.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96; platform_system == "Linux" and platform_machine == "x86_64" in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (8.5.0.96)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64" in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (10.2.10.91)
# Requirement already satisfied: triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64" in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (2.0.0)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1; platform_system == "Linux" and platform_machine == "x86_64" in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (11.4.0.1)
# Requirement already satisfied: filelock in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (3.12.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101; platform_system == "Linux" and platform_machine == "x86_64" in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (11.7.101)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91; platform_system == "Linux" and platform_machine == "x86_64" in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (11.7.4.91)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91; platform_system == "Linux" and platform_machine == "x86_64" in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (11.7.91)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux" and platform_machine == "x86_64" in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (11.10.3.66)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3; platform_system == "Linux" and platform_machine == "x86_64" in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (2.14.3)
# Requirement already satisfied: sympy in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (1.11.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (11.7.99)
# Requirement already satisfied: jinja2 in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (3.1.2)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58; platform_system == "Linux" and platform_machine == "x86_64" in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (10.9.0.58)
# Requirement already satisfied: networkx in /home/ali/.local/lib/python3.8/site-packages (from torch>=1.7.1->grad-cam) (3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ali/.local/lib/python3.8/site-packages (from matplotlib->grad-cam) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ali/.local/lib/python3.8/site-packages (from matplotlib->grad-cam) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ali/.local/lib/python3.8/site-packages (from matplotlib->grad-cam) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/ali/.local/lib/python3.8/site-packages (from matplotlib->grad-cam) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ali/.local/lib/python3.8/site-packages (from matplotlib->grad-cam) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/ali/.local/lib/python3.8/site-packages (from matplotlib->grad-cam) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/ali/.local/lib/python3.8/site-packages (from matplotlib->grad-cam) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ali/.local/lib/python3.8/site-packages (from matplotlib->grad-cam) (3.0.9)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.7.1->grad-cam) (45.2.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.7.1->grad-cam) (0.34.2)
# Requirement already satisfied: cmake in /home/ali/.local/lib/python3.8/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.7.1->grad-cam) (3.26.3)
# Requirement already satisfied: lit in /home/ali/.local/lib/python3.8/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.7.1->grad-cam) (16.0.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ali/.local/lib/python3.8/site-packages (from sympy->torch>=1.7.1->grad-cam) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ali/.local/lib/python3.8/site-packages (from jinja2->torch>=1.7.1->grad-cam) (2.1.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->grad-cam) (1.14.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/ali/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib->grad-cam) (3.15.0)

# %%
import sys
sys.path.append('/')

import cv2
import numpy as np
from torchvision import models
from efficientnet_pytorch import EfficientNet
#from grad_cam import GradCam,GuidedBackpropReLUModel,show_cams,show_gbs,preprocess_image

from grad_cam import GradCAM
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 10
#       7 from efficientnet_pytorch import EfficientNet
#       8 #from grad_cam import GradCam,GuidedBackpropReLUModel,show_cams,show_gbs,preprocess_image
# ---> 10 from grad_cam import GradCAM
#
# ModuleNotFoundError: No module named 'grad_cam'

# %%
model = EfficientNet.from_pretrained('efficientnet-b0')
grad_cam = GradCam(model=model, blob_name = '_blocks', target_layer_names=['1','10','15'], use_cuda=False)
img = cv2.imread('flower/Train/rose/102501987_3cdb8e5394_n.jpg', 1)
img = np.float32(cv2.resize(img, (224, 224))) / 255
inputs = preprocess_image(img)
# If None, returns the map for the highest scoring category.
# Otherwise, targets the requested index.
target_index = None
mask_dic = grad_cam(inputs, target_index)
show_cams(img, mask_dic)
gb_model = GuidedBackpropReLUModel(model=model, activation_layer_name = 'MemoryEfficientSwish', use_cuda=False)
show_gbs(inputs, gb_model, target_index, mask_dic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = EfficientNet.from_pretrained('efficientnet-b0')
#       2 grad_cam = GradCam(model=model, blob_name = '_blocks', target_layer_names=['1','10','15'], use_cuda=False)
#       3 img = cv2.imread('flower/Train/rose/102501987_3cdb8e5394_n.jpg', 1)
#
# NameError: name 'EfficientNet' is not defined
